# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
    
df = pd.read_csv('dataset_1.csv', index_col='Unnamed: 0')
df
# Out:
#      normalized_age  normalized_salary
# 0          0.680267          -0.016342
# 1          3.809518           0.798483
# 2         -1.661372          -0.577667
# 3         -0.257307          -0.155552
# 4          0.698017           0.174561
# ..              ...                ...
# 995       -5.060165           2.482045
# 996       -5.079404           2.773580
# 997       -5.861520           3.068426
# 998       -5.018934           3.110904
# 999       -6.799331           2.082321
#
# [1000 rows x 2 columns]

# %%
df.shape
# Out:
# (1000, 2)

# %%
df.isnull().sum()
# Out:
# normalized_age       0
# normalized_salary    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized_age     1000 non-null   float64
#  1   normalized_salary  1000 non-null   float64
# dtypes: float64(2)
# memory usage: 23.4 KB

# %%
df.describe()
# Out:
#        normalized_age  normalized_salary
# count     1000.000000        1000.000000
# mean        -3.013713           1.500108
# std          3.242532           1.604930
# min         -8.096229          -1.190175
# 25%         -5.971419          -0.016512
# 50%         -4.317377           1.138382
# 75%         -0.059299           2.983284
# max          4.690904           4.850055

# %%
df.plot.scatter('normalized_age', 'normalized_salary')

# %%
X = df.values
X
# Out:
# array([[ 0.68026725, -0.01634235],
#        [ 3.80951844,  0.79848348],
#        [-1.6613724 , -0.57766695],
#        ...,
#        [-5.86152028,  3.06842556],
#        [-5.01893361,  3.11090369],
#        [-6.79933099,  2.08232074]])

# %%
def generate_centroids(X, k):
    indice1, indice2, indice3 = np.random.randint(X.shape[0], size=k)
    centroid1 = X[indice1]
    centroid2 = X[indice2]
    centroid3 = X[indice3]
    return centroid1, centroid2

# %%
def generate_label(X, centroid):
    distance_btw_centr = []
    for centroïde in centroid:
        for i in X:
            dist = np.linalg.norm(centroïde-i)
            distance_btw_centr.append(dist)
        print(distance_btw_centr)

generate_label(X, generate_centroids(X, 3))
# Out:
# [0.21340453917024024, 3.427518118507997, 2.215283845410478, 0.74976966358288, 0.27275348471415495, 2.074047770870525, 0.2687731895449923, 0.11653201790062552, 0.858306803070307, 1.963163779030667, 0.8081741879863215, 1.7795678439218545, 3.05860101952505, 0.7956294644927389, 2.068394352936704, 0.2053689219165006, 3.9063566004507626, 0.2176661959768404, 1.6084389274468769, 0.990290737567914, 2.925532555483737, 2.9928464738377007, 1.2244004944305547, 0.9457173864765008, 0.8339910992703421, 0.2891175654674725, 2.5174047284733336, 0.29813856805679845, 0.10040645515983104, 1.0924499420054954, 1.0865736300216677, 3.4637044073471612, 1.1713132204201346, 0.4528176343887782, 0.39229350342266267, 0.2554365153947584, 2.6463915911070894, 1.6694359571959674, 1.4644312219882818, 0.37638026121824986, 1.1534017688836213, 3.1574771357389073, 2.8139537426214605, 0.8054220328585208, 1.415065499388049, 1.685065820745921, 1.2388935202188
395719166063122, 3.010461422978722, 1.4815253063694342, 1.0270088381257494, 0.7340581468683262, 2.867160088590532, 0.6817473891153173, 1.3366155969795108, 0.5602409005267025, 0.28739060705039027, 0.3229614712715299, 0.30857948684503944, 5.315094964302482, 0.20265124897701822, 1.1411118348420497, 0.6786922811986246, 3.2008284512296803, 1.3239911818732846, 2.2405430793289227, 0.5958136319302145, 1.6858107886603324, 1.7942285779629885, 1.2975345374390168, 2.3717568278770385, 1.5281099986383402, 0.5572930220535859, 0.22809710140110573, 2.47118230446626, 1.6516045987152632, 1.2836600996291692, 2.7932600137151886, 0.7583982317162854, 1.4249740573477254, 1.7248738977893363, 0.3146740555302432, 0.9677670166108515, 0.6559077606655419, 1.8733756347042136, 2.026663351556595, 1.0021236741629422, 3.4826101380226806, 1.2095800134663335, 2.557177438120674, 2.548919527506188, 0.7406066949607467, 0.44481221028311624, 2.4549727642888968, 1.280058031823897, 2.572641326045267, 0.9517341591148933, 0.21772115887387203, 0.13671670873473354, 2.961396137323625, 1.699642404878009, 1.366955718984082, 1.2836060644536553, 0.6442780308636034, 0.47333623578666456, 0.10891915940247125, 0.201547630413703, 1.1534625996156587, 2.4300086935376735, 2.2052165983109457, 0.9185745143757422, 0.4056031426342259, 3.221418490648081, 1.083345815430035, 0.35461559968445683, 2.2186495445891223, 3.358819277685692, 3.016916073432344, 0.22758110402186818, 0.8660098536645768, 3.2807476882279802, 1.7904072147652292, 1.5095659717715726, 0.9933989659674383, 2.4030024292206913, 0. ...

# %%
def compute_new_cendroid_position(X, label):
	"""
	retourn la position des nouveaux cenroids

	"""
	return new_centroid1, new_centroid2

# %%
def plot_graph(X, label, centroid1, centroid2):
	"""
	retourn rien, affiche le graphe avec en coloration différente les clusters

	"""

# %%
centroid1 = generate_one_centroid(X)
centroid2 = generate_one_centroid(X)


label = generate_label(X, centroid1, centroid2)

new_centroid1, new_centroid2 = compute_new_cendroid_position(X, label)


while np.round(new_centroid1,3) != np.round(centroid1,3) and np.round(new_centroid2,3) != np.round(centroid2,3):
    centroid1, centroid2 = new_centroid1, new_centroid2
    label = generate_label(X, centroid1, centroid2)
    new_centroid1, new_centroid2 = compute_new_cendroid_position(X, label)
    plot_graph(X, label, centroid1, centroid2)

# %%
indice1, indice2 = np.random.randint(X.shape[0], size=2)
centroid1 = X[indice1]
centroid2 = X[indice2]

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.scatter(centroid1, centroid2, marker='x')

# %%
def distEuclidean(df, centroids):
    distance = 0
    for i in centroids:
        distance += (df[i] - centroids[i])**2
        
    resu = np.sqrt(distance)
    return resu

# %%
def knnPredict(train, test, k):
    distance = []
    iterations = 10
    while i < iterations:
